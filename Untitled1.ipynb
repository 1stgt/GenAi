# %%
from google.colab import userdata
git_pat = userdata.get('git_pat')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents
# Out:
# /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents/.git/

# %%
# !git remote add origin https://Yadav@250git:git_pat@github.com/Yadav@250git/GenAi.git

# !git remote -v
# Out:
# error: remote origin already exists.
# origin	https://{1stgt}:{Yadav@250git}@github.com/{Yadav@250git}/{https://github.com/1stgt/GenAi.git}.git (fetch)
# origin	https://{1stgt}:{Yadav@250git}@github.com/{Yadav@250git}/{https://github.com/1stgt/GenAi.git}.git (push)

# %%
# !git config --global user.email '{1st19cs047@gmail.com}'
# !git config --global user.name '{1stgt}'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master d1a311b] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled1.ipynb (96%)

# %%
# !git push origin master
# Out:
# fatal: unable to access 'https://250git}@github.com/{Yadav@250git}/{https://github.com/1stgt/GenAi.git}.git/': URL using bad/illegal format or missing URL

# %%
from google.colab import drive, userdata

# Mount Google Drive
drive.mount('/content/gdrive')

# Change to the directory where your project is located
# %cd /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents

# Get the GitHub Personal Access Token (PAT) and GitHub username securely
git_pat = userdata.get('git_pat')
git_username = 'Yadav@250git'

# Reinitialize the Git repository (if needed)
# !git init

# Add the correct remote URL
# !git remote remove origin  # Remove the existing remote to avoid conflicts
# !git remote add origin https://{git_username}:{git_pat}@github.com/{git_username}/GenAi.git

# Configure Git with your name and email
# !git config --global user.email '1st19cs047@gmail.com'
# !git config --global user.name 'Harsh Kumar Yadav'

# Add and commit your files
# !git add .
# !git commit -m 'First commit'

# Push to GitHub
# !git push origin master
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents
# Reinitialized existing Git repository in /content/gdrive/My Drive/Colab Notebooks/GenAi/Agents/.git/
# error: remote origin already exists.
# [master 7e03e56] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: unable to access 'https://250git}@github.com/{Yadav@250git}/{https://github.com/1stgt/GenAi.git}.git/': URL using bad/illegal format or missing URL
